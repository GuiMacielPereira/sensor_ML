# %%
from peratouch.routines import run_network
from peratouch.data import load_data
from peratouch.config import path_five_users_main, path_five_users_first

# %%
from peratouch.networks import CNN
Xraw, yraw = load_data(path_five_users_main)
_ = run_network(CNN, Xraw, yraw, n_ch=1, n_epochs=10, n_folds=5, n_runs=1, plots=True, n_batches=20, random_resampling=False)

# %%
from peratouch.networks import LSTM 
Xraw, yraw = load_data(path_five_users_main)
_ = run_network(LSTM, Xraw, yraw, input_size=32, hidden_size=16, n_ch=1, n_epochs=10, n_folds=5, n_runs=1, plots=True, n_batches=20, random_resampling=False)
# Out:
# -- New Fold --
# Train, test and validation arrays normalized to:
# [1.], [1.0006], [0.9997]
# Using Device:  cpu , dtype:  torch.float32
#
# Raw data shape:  (106425, 1, 32)
# Labels shape:  (106425,)
# Shape of test set: (21285, 1, 32)
# Shape of train set: (72369, 1, 32)
# Shape of validation set: (12771, 1, 32)
# Unique labels:  [0 1 2 3 4]
# Fraction of test labels:  [0.23, 0.18, 0.21, 0.21, 0.17]
# Fraction of validation labels:  [0.23, 0.18, 0.2, 0.21, 0.16]
# Fraction of train labels:  [0.22, 0.19, 0.21, 0.21, 0.17]
# dtype of inputs:  torch.float32
#
#  Start of training model:
#
# End of epoch 1: loss_tr=1.398, loss_val=1.394, train=44.9%, val=45.7%
# End of epoch 2: loss_tr=1.322, loss_val=1.316, train=44.7%, val=45.1%
# End of epoch 3: loss_tr=1.273, loss_val=1.270, train=45.1%, val=45.1%
# End of epoch 4: loss_tr=1.231, loss_val=1.224, train=49.6%, val=50.4%
# End of epoch 5: loss_tr=1.230, loss_val=1.227, train=46.8%, val=46.8%
# End of epoch 6: loss_tr=1.240, loss_val=1.241, train=47.6%, val=47.8%
# End of epoch 7: loss_tr=1.156, loss_val=1.155, train=51.4%, val=51.6%
# End of epoch 8: loss_tr=1.133, loss_val=1.126, train=55.3%, val=55.5%
# End of epoch 9: loss_tr=1.110, loss_val=1.105, train=56.8%, val=56.9%
# End of epoch 10: loss_tr=1.154, loss_val=1.148, train=54.2%, val=54.6%
#
# Training Complete!
# Loading best weights for lowest validation loss=1.105 ...
#
# Average running time per epoch: 0.44 seconds
# Total running time: 3.97 seconds
#
# Test dataset metrics:
# Overall Accuracy = 57.2%, Matthews Corr Coef = 0.47
#
#
#               precision    recall  f1-score   support
#
#            0       0.54      0.69      0.61      4852
#            1       0.68      0.43      0.53      3937
#            2       0.60      0.66      0.63      4544
#            3       0.56      0.74      0.64      4420
#            4       0.49      0.24      0.32      3532
#
#     accuracy                           0.57     21285
#    macro avg       0.57      0.55      0.54     21285
# weighted avg       0.57      0.57      0.56     21285

# %%
from peratouch.networks import CNN_LSTM 
Xraw, yraw = load_data(path_five_users_main)
_ = run_network(CNN_LSTM, Xraw, yraw, n_ch=1, n_epochs=10, n_folds=5, n_runs=1, plots=True, n_batches=20, random_resampling=False)
# Out:
# -- New Fold --
# Train, test and validation arrays normalized to:
# [1.], [1.0006], [0.9997]
# Using Device:  cpu , dtype:  torch.float32
#
# Raw data shape:  (106425, 1, 32)
# Labels shape:  (106425,)
# Shape of test set: (21285, 1, 32)
# Shape of train set: (72369, 1, 32)
# Shape of validation set: (12771, 1, 32)
# Unique labels:  [0 1 2 3 4]
# Fraction of test labels:  [0.23, 0.18, 0.21, 0.21, 0.17]
# Fraction of validation labels:  [0.23, 0.18, 0.2, 0.21, 0.16]
# Fraction of train labels:  [0.22, 0.19, 0.21, 0.21, 0.17]
# dtype of inputs:  torch.float32
#
#  Start of training model:
#
# End of epoch 1: loss_tr=1.207, loss_val=1.206, train=52.2%, val=52.5%
# End of epoch 2: loss_tr=1.095, loss_val=1.097, train=57.9%, val=58.0%
# End of epoch 3: loss_tr=1.066, loss_val=1.066, train=58.5%, val=58.8%
# End of epoch 4: loss_tr=1.045, loss_val=1.048, train=59.2%, val=59.2%
# End of epoch 5: loss_tr=1.017, loss_val=1.026, train=60.7%, val=60.2%
# End of epoch 6: loss_tr=1.008, loss_val=1.017, train=61.2%, val=60.9%
# End of epoch 7: loss_tr=0.936, loss_val=0.948, train=64.1%, val=63.9%
# End of epoch 8: loss_tr=0.944, loss_val=0.955, train=62.7%, val=62.6%
# End of epoch 9: loss_tr=0.910, loss_val=0.920, train=65.4%, val=65.0%
# End of epoch 10: loss_tr=0.903, loss_val=0.913, train=65.2%, val=65.1%
#
# Training Complete!
# Loading best weights for lowest validation loss=0.913 ...
#
# Average running time per epoch: 1.72 seconds
# Total running time: 15.45 seconds
#
# Test dataset metrics:
# Overall Accuracy = 65.1%, Matthews Corr Coef = 0.56
#
#
#               precision    recall  f1-score   support
#
#            0       0.68      0.62      0.65      4852
#            1       0.70      0.75      0.72      3937
#            2       0.74      0.64      0.69      4544
#            3       0.60      0.66      0.63      4420
#            4       0.54      0.59      0.56      3532
#
#     accuracy                           0.65     21285
#    macro avg       0.65      0.65      0.65     21285
# weighted avg       0.66      0.65      0.65     21285
